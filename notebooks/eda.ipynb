# %%
import pandas as pd
from recsys.src.data import read_parquet

# %%
FILE_NAMES = ["rating", "movies", "tags", "genome-scores", "genome-tags"]
df_list: list = read_parquet(FILE_NAMES)
